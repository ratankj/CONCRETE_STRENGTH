# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

warnings.filterwarnings("ignore")
# %matplotlib inline

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer

# %%
df=pd.read_csv(r"F:\Ineuron projects\Concrete Stength prediction\note_book\ConcreteStrengthData.csv")

# %%
df1=df.copy()

# %%
df.head()
# Out:
#    CementComponent   BlastFurnaceSlag  FlyAshComponent  WaterComponent  \
# 0             540.0               0.0              0.0           162.0
# 1             540.0               0.0              0.0           162.0
# 2             332.5             142.5              0.0           228.0
# 3             332.5             142.5              0.0           228.0
# 4             198.6             132.4              0.0           192.0
#
#    SuperplasticizerComponent  CoarseAggregateComponent  \
# 0                        2.5                    1040.0
# 1                        2.5                    1055.0
# 2                        0.0                     932.0
# 3                        0.0                     932.0
# 4                        0.0                     978.4
#
#    FineAggregateComponent  AgeInDays  Strength
# 0                   676.0         28     79.99
# 1                   676.0         28     61.89
# 2                   594.0        270     40.27
# 3                   594.0        365     41.05
# 4                   825.5        360     44.30

# %%
df.tail()
# Out:
#       CementComponent   BlastFurnaceSlag  FlyAshComponent  WaterComponent  \
# 1025             276.4             116.0             90.3           179.6
# 1026             322.2               0.0            115.6           196.0
# 1027             148.5             139.4            108.6           192.7
# 1028             159.1             186.7              0.0           175.6
# 1029             260.9             100.5             78.3           200.6
#
#       SuperplasticizerComponent  CoarseAggregateComponent  \
# 1025                        8.9                     870.1
# 1026                       10.4                     817.9
# 1027                        6.1                     892.4
# 1028                       11.3                     989.6
# 1029                        8.6                     864.5
#
#       FineAggregateComponent  AgeInDays  Strength
# 1025                   768.3         28     44.28
# 1026                   813.4         28     31.18
# 1027                   780.0         28     23.70
# 1028                   788.9         28     32.77
# 1029                   761.5         28     32.40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CementComponent            1030 non-null   float64
#  1   BlastFurnaceSlag           1030 non-null   float64
#  2   FlyAshComponent            1030 non-null   float64
#  3   WaterComponent             1030 non-null   float64
#  4   SuperplasticizerComponent  1030 non-null   float64
#  5   CoarseAggregateComponent   1030 non-null   float64
#  6   FineAggregateComponent     1030 non-null   float64
#  7   AgeInDays                  1030 non-null   int64
#  8   Strength                   1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
df.isnull().sum()
# Out:
# CementComponent              0
# BlastFurnaceSlag             0
# FlyAshComponent              0
# WaterComponent               0
# SuperplasticizerComponent    0
# CoarseAggregateComponent     0
# FineAggregateComponent       0
# AgeInDays                    0
# Strength                     0
# dtype: int64

# %%
df.corr()
# Out:
#                            CementComponent   BlastFurnaceSlag  \
# CementComponent                    1.000000         -0.275216
# BlastFurnaceSlag                  -0.275216          1.000000
# FlyAshComponent                   -0.397467         -0.323580
# WaterComponent                    -0.081587          0.107252
# SuperplasticizerComponent          0.092386          0.043270
# CoarseAggregateComponent          -0.109349         -0.283999
# FineAggregateComponent            -0.222718         -0.281603
# AgeInDays                          0.081946         -0.044246
# Strength                           0.497832          0.134829
#
#                            FlyAshComponent  WaterComponent  \
# CementComponent                  -0.397467       -0.081587
# BlastFurnaceSlag                 -0.323580        0.107252
# FlyAshComponent                   1.000000       -0.256984
# WaterComponent                   -0.256984        1.000000
# SuperplasticizerComponent         0.377503       -0.657533
# CoarseAggregateComponent         -0.009961       -0.182294
# FineAggregateComponent            0.079108       -0.450661
# AgeInDays                        -0.154371        0.277618
# Strength                         -0.105755       -0.289633
#
#                            SuperplasticizerComponent  \
# CementComponent                             0.092386
# BlastFurnaceSlag                            0.043270
# FlyAshComponent                             0.377503
# WaterComponent                             -0.657533
# SuperplasticizerComponent                   1.000000
# CoarseAggregateComponent                   -0.265999
# FineAggregateComponent                      0.222691
# AgeInDays                                  -0.192700
# Strength                                    0.366079
#
#                            CoarseAggregateComponent  FineAggregateComponent  \
# CementComponent                           -0.109349               -0.222718
# BlastFurnaceSlag                          -0.283999               -0.281603
# FlyAshComponent                           -0.009961                0.079108
# WaterComponent                            -0.182294               -0.450661
# SuperplasticizerComponent                 -0.265999                0.222691
# CoarseAggregateComponent                   1.000000               -0.178481
# FineAggregateComponent                    -0.178481                1.000000
# AgeInDays                                 -0.003016               -0.156095
# Strength                                  -0.164935               -0.167241
#
#                            AgeInDays  Strength
# CementComponent             0.081946  0.497832
# BlastFurnaceSlag           -0.044246  0.134829
# FlyAshComponent            -0.154371 -0.105755
# WaterComponent              0.277618 -0.289633
# SuperplasticizerComponent  -0.192700  0.366079
# CoarseAggregateComponent   -0.003016 -0.164935
# FineAggregateComponent     -0.156095 -0.167241
# AgeInDays                   1.000000  0.328873
# Strength                    0.328873  1.000000

# %%
df.columns
# Out:
# Index(['CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent',
#        'WaterComponent', 'SuperplasticizerComponent',
#        'CoarseAggregateComponent', 'FineAggregateComponent', 'AgeInDays',
#        'Strength'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CementComponent   BlastFurnaceSlag  FlyAshComponent  WaterComponent  \
# count       1030.000000       1030.000000      1030.000000     1030.000000
# mean         281.167864         73.895825        54.188350      181.567282
# std          104.506364         86.279342        63.997004       21.354219
# min          102.000000          0.000000         0.000000      121.800000
# 25%          192.375000          0.000000         0.000000      164.900000
# 50%          272.900000         22.000000         0.000000      185.000000
# 75%          350.000000        142.950000       118.300000      192.000000
# max          540.000000        359.400000       200.100000      247.000000
#
#        SuperplasticizerComponent  CoarseAggregateComponent  \
# count                1030.000000               1030.000000
# mean                    6.204660                972.918932
# std                     5.973841                 77.753954
# min                     0.000000                801.000000
# 25%                     0.000000                932.000000
# 50%                     6.400000                968.000000
# 75%                    10.200000               1029.400000
# max                    32.200000               1145.000000
#
#        FineAggregateComponent    AgeInDays     Strength
# count             1030.000000  1030.000000  1030.000000
# mean               773.580485    45.662136    35.817961
# std                 80.175980    63.169912    16.705742
# min                594.000000     1.000000     2.330000
# 25%                730.950000     7.000000    23.710000
# 50%                779.500000    28.000000    34.445000
# 75%                824.000000    56.000000    46.135000
# max                992.600000   365.000000    82.600000

# %% [markdown]
# Remove Duplicates

# %%
def remove_duplicates(data):
    print('Shape before deleting duplicate values:', data.shape)
    
    # Removing duplicate rows if any
    data = data.drop_duplicates()
    
    print('Shape after deleting duplicate values:', data.shape)
    return data
df=remove_duplicates(df)
# Out:
# Shape before deleting duplicate values: (1030, 9)
# Shape after deleting duplicate values: (1005, 9)

# %% [markdown]
# Unique value percentage

# %%
def plot_unique_value_percentage(data):
    unique_percentage = (data.nunique() / len(data)) * 100
    ax = unique_percentage.plot(kind='bar', figsize=(10, 6))
    
    ax.set_title('Percentage of Unique Values in Columns')
    ax.set_xlabel('Columns')
    ax.set_ylabel('Percentage (%)')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')
    
    plt.show()

plot_unique_value_percentage(df)

# %% [markdown]
# #### Target Dist Plot

# %%
# %matplotlib inline
# Creating Bar chart as the Target variable is Continuous
df['Strength'].hist()
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# CementComponent              float64
# BlastFurnaceSlag             float64
# FlyAshComponent              float64
# WaterComponent               float64
# SuperplasticizerComponent    float64
# CoarseAggregateComponent     float64
# FineAggregateComponent       float64
# AgeInDays                      int64
# Strength                     float64
# dtype: object

# %%
numerical_col =[feature for feature in df.columns if df[feature].dtypes != 'o']

# %%
plt.figure(figsize=(20, 25))
for i, col in enumerate(numerical_col):
    plt.subplot(5, 2, i+1)
    sns.distplot(x=df[col], color='indianred')
    plt.xlabel(col, weight='bold')
    plt.tight_layout()

# %% [markdown]
# ##### Data Skewness

# %% [markdown]
# · If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
#
# · If the skewness is between -1 and — 0.5 or between 0.5 and 1, the data are moderately skewed
#
# · If the skewness is less than -1 or greater than 1, the data are highly skewed

# %%
def check_skewness(df, numerical_col):
    for i in numerical_col:
        skewness = df[i].skew()
        if -0.5 <= skewness <= 0.5:
            print(f"Skewness of {i} column is: {skewness} - Data is normally distributed or fairly symmetrical")
        elif -0.5 > skewness > -1 or 0.5 < skewness < 1:
            print(f"Skewness of {i} column is: {skewness} - Moderately skewed")
        else:
            print(f"Skewness of {i} column is: {skewness} - Highly skewed")
        print()

check_skewness(df, numerical_col)
# Out:
# Skewness of CementComponent  column is: 0.5649589710818717 - Moderately skewed
#
# Skewness of BlastFurnaceSlag column is: 0.8552248976041229 - Moderately skewed
#
# Skewness of FlyAshComponent column is: 0.4972312662135868 - Data is normally distributed or fairly symmetrical
#
# Skewness of WaterComponent column is: 0.034433208021637955 - Data is normally distributed or fairly symmetrical
#
# Skewness of SuperplasticizerComponent column is: 0.9806043204539713 - Moderately skewed
#
# Skewness of CoarseAggregateComponent column is: -0.065255998835077 - Data is normally distributed or fairly symmetrical
#
# Skewness of FineAggregateComponent column is: -0.25235318089800507 - Data is normally distributed or fairly symmetrical
#
# Skewness of AgeInDays column is: 3.2539737173312044 - Highly skewed
#
# Skewness of Strength column is: 0.3956961343153939 - Data is normally distributed or fairly symmetrical

# %% [markdown]
# cement ,blast_furnace_slag ,fly_ash ,superplasticizer ,concrete_compressive_strength

# %% [markdown]
# ##### Log Transform

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()

# %%
df.columns
# Out:
# Index(['CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent',
#        'WaterComponent', 'SuperplasticizerComponent',
#        'CoarseAggregateComponent', 'FineAggregateComponent', 'AgeInDays',
#        'Strength'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt

columns = [ 'CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent', 'SuperplasticizerComponent',
           'CoarseAggregateComponent']

for column in columns:
    # Filter out negative or zero values
    positive_data = df[column][df[column] > 0]

    # Apply natural logarithm transformation
    log_transformed = np.log(positive_data)


    # Plot histogram of log-transformed data
    plt.hist(log_transformed, bins=30)
    plt.xlabel(f'Log-transformed Data ({column})')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of Log-transformed Data ({column})')
    plt.show()

# %%
df.columns
# Out:
# Index(['CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent',
#        'WaterComponent', 'SuperplasticizerComponent',
#        'CoarseAggregateComponent', 'FineAggregateComponent', 'AgeInDays',
#        'Strength'],
#       dtype='object')

# %% [markdown]
# Scatter Plot

# %%
ContinuousCols=['CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent',
                'WaterComponent', 'SuperplasticizerComponent','Strength', 
                'AgeInDays']

# Plotting scatter chart for each predictor vs the target variable
for predictor in ContinuousCols:
    df.plot.scatter(x=predictor, y='Strength', figsize=(10,5), title=predictor+" VS "+ 'Strength')

# %% [markdown]
# Numerical columns

# %%
df.columns
# Out:
# Index(['CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent',
#        'WaterComponent', 'SuperplasticizerComponent',
#        'CoarseAggregateComponent', 'FineAggregateComponent', 'AgeInDays',
#        'Strength'],
#       dtype='object')

# %%
numerical_col=['CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent',
                'WaterComponent', 'SuperplasticizerComponent','CoarseAggregateComponent', 
                'AgeInDays']

# %% [markdown]
# Input and target Feature

# %%
X = df.drop(labels=['Strength'],axis=1)
y = df[['Strength']]

# %%
X.head()
# Out:
#    CementComponent   BlastFurnaceSlag  FlyAshComponent  WaterComponent  \
# 0             540.0               0.0              0.0           162.0
# 1             540.0               0.0              0.0           162.0
# 2             332.5             142.5              0.0           228.0
# 3             332.5             142.5              0.0           228.0
# 4             198.6             132.4              0.0           192.0
#
#    SuperplasticizerComponent  CoarseAggregateComponent  \
# 0                        2.5                    1040.0
# 1                        2.5                    1055.0
# 2                        0.0                     932.0
# 3                        0.0                     932.0
# 4                        0.0                     978.4
#
#    FineAggregateComponent  AgeInDays
# 0                   676.0         28
# 1                   676.0         28
# 2                   594.0        270
# 3                   594.0        365
# 4                   825.5        360

# %%
y.head()
# Out:
#    Strength
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# 4     44.30

# %% [markdown]
# Train Test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
def create_numerical_pipeline(numerical_col):
    numerical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler()),
        ('power', PowerTransformer(method='yeo-johnson', standardize=False))
    ])
    preprocessor = ColumnTransformer([
        ('numerical_pipeline', numerical_pipeline, numerical_col)
    ])
    return preprocessor
preprocessor=create_numerical_pipeline(numerical_col=numerical_col)

# %%
X_train=preprocessor.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.79772665, -1.19331916, -1.12461072, ...,  2.32203905,
#         -1.53788373, -1.20907314],
#        [ 1.46535518, -1.19331916, -1.12461072, ..., -1.25748775,
#         -0.52254396, -1.04254209],
#        [-0.01046428, -1.19331916,  0.53273104, ...,  0.79798339,
#          0.0167691 , -1.20907314],
#        ...,
#        [-1.46386135,  0.61183874,  0.6964306 , ...,  0.29955176,
#         -1.3495293 , -0.35776953],
#        [-1.30401069,  0.50293241,  0.8779039 , ...,  0.3140839 ,
#          0.4319012 ,  0.47941924],
#        [ 0.07687568,  0.91060852, -1.12461072, ...,  0.72551289,
#          0.41622076, -1.04254209]])

# %%
X_test=preprocessor.transform(X_test)

# %%
from xgboost import XGBRegressor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor



from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# evaluate Reg - Metrics

# %%
def evaluate_reg(true, predicted):
    r2 = r2_score(true, predicted) # Calculate r2 score
    MAE = mean_absolute_error(true, predicted) # Calculate MAE
    MSE = mean_squared_error(true, predicted) # Calculate MSE
    rmse = np.sqrt(mean_squared_error(true, predicted))

   
    return r2, MAE , MSE,rmse

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, Lasso
from xgboost import XGBRegressor

# %%
models = {
    "Random Forest": RandomForestRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "Linear Regression": LinearRegression(),
    "Ridge": Lasso(),
    "XGBRegressor": XGBRegressor(),
    "AdaBoost": AdaBoostRegressor()
}

results = pd.DataFrame(columns=['Model', 'r2_score_test', 'r2_score_train', 'MAE_test', 'MSE_test', 'rmse', 'MAE_train', 'MSE_train', 'rmse_train'])

for model_name, model in models.items():
    model.fit(X_train, y_train)  # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Test set performance
    r2, MAE, MSE, rmse = evaluate_reg(y_test, y_test_pred)
    r2_train, MAE_train, MSE_train, rmse_train = evaluate_reg(y_train, y_train_pred)

    result = {
        'Model': model_name,
        'r2_score_test': r2,
        'r2_score_train': r2_train,
        'MAE': MAE,
        'MSE': MSE,
        'rmse': rmse,
        'MAE_train': MAE_train,
        'MSE_train': MSE_train,
        'rmse_train': rmse_train
    }

    results = results.append(result, ignore_index=True)

    print(model_name)
    print('Model performance for Test set')
    print('- r2_score: {:.4f}'.format(r2))
    print('- MAE: {:.4f}'.format(MAE))
    print('- MSE: {:.4f}'.format(MSE))
    print('- rmse: {:.4f}'.format(rmse))

    print('Model performance for train set')
    print('- r2_score: {:.4f}'.format(r2_train))
    print('- MAE: {:.4f}'.format(MAE_train))
    print('- MSE: {:.4f}'.format(MSE_train))
    print('- rmse: {:.4f}'.format(rmse_train))

    print('=' * 35)
    print('=' * 35)
    print('\n')

print(results)
# Out:
# Random Forest
# Model performance for Test set
# - r2_score: 0.9064
# - MAE: 3.5058
# - MSE: 27.9321
# - rmse: 5.2851
# Model performance for train set
# - r2_score: 0.9835
# - MAE: 1.3805
# - MSE: 4.2189
# - rmse: 2.0540
# ===================================
# ===================================
#
#
# Decision Tree
# Model performance for Test set
# - r2_score: 0.9006
# - MAE: 3.5880
# - MSE: 29.6572
# - rmse: 5.4458
# Model performance for train set
# - r2_score: 0.9964
# - MAE: 0.0944
# - MSE: 0.9245
# - rmse: 0.9615
# ===================================
# ===================================
#
#
# Gradient Boosting
# Model performance for Test set
# - r2_score: 0.8887
# - MAE: 4.2390
# - MSE: 33.2042
# - rmse: 5.7623
# Model performance for train set
# - r2_score: 0.9387
# - MAE: 3.0020
# - MSE: 15.7310
# - rmse: 3.9662
# ===================================
# ===================================
#
#
# Linear Regression
# Model performance for Test set
# - r2_score: 0.8009
# - MAE: 5.9683
# - MSE: 59.3923
# - rmse: 7.7066
# Model performance for train set
# - r2_score: 0.8107
# - MAE: 5.3609
# - MSE: 48.5301
# - rmse: 6.9664
# ===================================
# ===================================
#
#
# Ridge
# Model performance for Test set
# - r2_score: 0.7289
# - MAE: 6.9938
# - MSE: 80.8654
# - rmse: 8.9925
# Model performance for train set
# - r2_score: 0.7578
# - MAE: 6.2655
# - MSE: 62.1045
# - rmse: 7.8806
# ===================================
# ===================================
#
#
# XGBRegressor
# Model performance for Test set
# - r2_score: 0.9288
# - MAE: 2.8693
# - MSE: 21.2321
# - rmse: 4.6078
# Model performance for train set
# - r2_score: 0.9953
# - MAE: 0.4287
# - MSE: 1.1949
# - rmse: 1.0931
# ===================================
# ===================================
#
#
# AdaBoost
# Model performance for Test set
# - r2_score: 0.7741
# - MAE: 6.5700
# - MSE: 67.3872
# - rmse: 8.2090
# Model performance for train set
# - r2_score: 0.8052
# - MAE: 5.9547
# - MSE: 49.9494
# - rmse: 7.0675
# ===================================
# ===================================
#
#
#                Model  r2_score_test  r2_score_train MAE_test MSE_test  \
# 0      Random Forest       0.906370        0.983547      NaN      NaN
# 1      Decision Tree       0.900588        0.996395      NaN      NaN
# 2  Gradient Boosting       0.888698        0.938650      NaN      NaN
# 3  Linear Regression       0.800914        0.810736      NaN      NaN
# 4              Ridge       0.728935        0.757797      NaN      NaN
# 5       XGBRegressor       0.928829        0.995340      NaN      NaN
# 6           AdaBoost       0.774115        0.805201      NaN      NaN
#
#        rmse  MAE_train  MSE_train  rmse_train       MAE        MSE
# 0  5.285081   1.380461   4.218877    2.053991  3.505759  27.932077
# 1  5.445838   0.094436   0.924483    0.961501  3.587985  29.657157
# 2  5.762312   3.001980  15.731011    3.966234  4.239050  33.204240
# 3  7.706642   5.360922  48.530094    6.966354  5.968272  59.392326
# 4  8.992522   6.265478  62.104465    7.880639  6.993759  80.865445
# 5  4.607825   0.428709   1.194938    1.093132  2.869276  21.232053
# 6  8.208973   5.954703  49.949381    7.067488  6.570003  67.387233

# %%
results
# Out:
#                Model  r2_score_test  r2_score_train MAE_test MSE_test  \
# 0      Random Forest       0.906370        0.983547      NaN      NaN
# 1      Decision Tree       0.900588        0.996395      NaN      NaN
# 2  Gradient Boosting       0.888698        0.938650      NaN      NaN
# 3  Linear Regression       0.800914        0.810736      NaN      NaN
# 4              Ridge       0.728935        0.757797      NaN      NaN
# 5       XGBRegressor       0.928829        0.995340      NaN      NaN
# 6           AdaBoost       0.774115        0.805201      NaN      NaN
#
#        rmse  MAE_train  MSE_train  rmse_train       MAE        MSE
# 0  5.285081   1.380461   4.218877    2.053991  3.505759  27.932077
# 1  5.445838   0.094436   0.924483    0.961501  3.587985  29.657157
# 2  5.762312   3.001980  15.731011    3.966234  4.239050  33.204240
# 3  7.706642   5.360922  48.530094    6.966354  5.968272  59.392326
# 4  8.992522   6.265478  62.104465    7.880639  6.993759  80.865445
# 5  4.607825   0.428709   1.194938    1.093132  2.869276  21.232053
# 6  8.208973   5.954703  49.949381    7.067488  6.570003  67.387233

# %% [markdown]
# ##### Lasso Regression - Feature Importance

# %%
from sklearn.linear_model import Lasso
numerical_col
lasso = Lasso(alpha=0.01)

lasso.fit(X_train, y_train)
lasso.coef_
# Out:
# array([11.40741657,  8.17526838,  3.99984953, -4.1764152 ,  0.95280489,
#         0.57489791, 16.4887808 ])

# %%
lasso.coef_
# Out:
# array([11.40741657,  8.17526838,  3.99984953, -4.1764152 ,  0.95280489,
#         0.57489791, 16.4887808 ])

# %%
numerical_col
# Out:
# ['CementComponent ',
#  'BlastFurnaceSlag',
#  'FlyAshComponent',
#  'WaterComponent',
#  'SuperplasticizerComponent',
#  'CoarseAggregateComponent',
#  'AgeInDays']

# %%
import matplotlib.pyplot as plt
import numpy as np

x = pd.Series(np.abs(lasso.coef_),index=numerical_col)
plt.figure(figsize=(12,8))
x.sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
feature_imp_lasso=x.sort_values(ascending=False).index
feature_imp_lasso
# Out:
# Index(['AgeInDays', 'CementComponent ', 'BlastFurnaceSlag', 'WaterComponent',
#        'FlyAshComponent', 'SuperplasticizerComponent',
#        'CoarseAggregateComponent'],
#       dtype='object')

# %% [markdown]
# ##### Random forest _ Feature Importance

# %%
rf = RandomForestRegressor()

#dt.fit(X_train,y_train)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.feature_importances_
# Out:
# array([0.32074508, 0.0886522 , 0.01829106, 0.09370283, 0.08596306,
#        0.03251291, 0.36013286])

# %%
x = pd.Series(np.abs(rf.feature_importances_),index=numerical_col)

x.sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
feature_imp_rf=x.sort_values(ascending=False).index
feature_imp_rf
# Out:
# Index(['AgeInDays', 'CementComponent ', 'WaterComponent', 'BlastFurnaceSlag',
#        'SuperplasticizerComponent', 'CoarseAggregateComponent',
#        'FlyAshComponent'],
#       dtype='object')

# %%
feature_imp_lasso
# Out:
# Index(['AgeInDays', 'CementComponent ', 'BlastFurnaceSlag', 'WaterComponent',
#        'FlyAshComponent', 'SuperplasticizerComponent',
#        'CoarseAggregateComponent'],
#       dtype='object')

# %%
feature_imp_rf
# Out:
# Index(['AgeInDays', 'CementComponent ', 'WaterComponent', 'BlastFurnaceSlag',
#        'SuperplasticizerComponent', 'CoarseAggregateComponent',
#        'FlyAshComponent'],
#       dtype='object')

# %% [markdown]
# ##### Model Training _ Selcted Features

# %%
selected_columns=['CementComponent ', 'AgeInDays', 'WaterComponent', 'BlastFurnaceSlag',
       'SuperplasticizerComponent']

# %% [markdown]
# Training Selected Features

# %%
df.head()
# Out:
#    CementComponent   BlastFurnaceSlag  FlyAshComponent  WaterComponent  \
# 0             540.0               0.0              0.0           162.0
# 1             540.0               0.0              0.0           162.0
# 2             332.5             142.5              0.0           228.0
# 3             332.5             142.5              0.0           228.0
# 4             198.6             132.4              0.0           192.0
#
#    SuperplasticizerComponent  CoarseAggregateComponent  \
# 0                        2.5                    1040.0
# 1                        2.5                    1055.0
# 2                        0.0                     932.0
# 3                        0.0                     932.0
# 4                        0.0                     978.4
#
#    FineAggregateComponent  AgeInDays  Strength
# 0                   676.0         28     79.99
# 1                   676.0         28     61.89
# 2                   594.0        270     40.27
# 3                   594.0        365     41.05
# 4                   825.5        360     44.30

# %%
df.columns
# Out:
# Index(['CementComponent ', 'BlastFurnaceSlag', 'FlyAshComponent',
#        'WaterComponent', 'SuperplasticizerComponent',
#        'CoarseAggregateComponent', 'FineAggregateComponent', 'AgeInDays',
#        'Strength'],
#       dtype='object')

# %%
df.shape
# Out:
# (1005, 9)

# %%
X=df[selected_columns]
y = df[['Strength']]

# %%
X.head()
# Out:
#    CementComponent   AgeInDays  WaterComponent  BlastFurnaceSlag  \
# 0             540.0         28           162.0               0.0
# 1             540.0         28           162.0               0.0
# 2             332.5        270           228.0             142.5
# 3             332.5        365           228.0             142.5
# 4             198.6        360           192.0             132.4
#
#    SuperplasticizerComponent
# 0                        2.5
# 1                        2.5
# 2                        0.0
# 3                        0.0
# 4                        0.0

# %%
X.shape
# Out:
# (1005, 5)

# %%
y.head()
# Out:
#    Strength
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# 4     44.30

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train.shape
# Out:
# (804, 5)

# %%
def create_numerical_pipeline(numerical_col):
    numerical_pipeline = Pipeline(steps=[
        ('impute', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler()),
        ('power', PowerTransformer(method='yeo-johnson', standardize=False))
    ])
    preprocessor = ColumnTransformer([
        ('numerical_pipeline', numerical_pipeline, numerical_col)
    ])
    return preprocessor

# %%
preprocessor=create_numerical_pipeline(numerical_col=selected_columns)

X_train=preprocessor.fit_transform(X_train)
X_test=preprocessor.transform(X_test)

# %%
X_train.shape
# Out:
# (804, 5)

# %% [markdown]
# Modle Training

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, Lasso
from xgboost import XGBRegressor
import pandas as pd

# %% [markdown]
# Model Hyper Parameters

# %%
models = {
    "Random Forest": RandomForestRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
 #   "Gradient Boosting": GradientBoostingRegressor(),
    "Linear Regression": LinearRegression(),
    "Ridge": Lasso(),
    "XGBRegressor": XGBRegressor(),
    "AdaBoost": AdaBoostRegressor()
}

param_grid = {
    "Random Forest": {'n_estimators': [100, 200, 300], 'max_depth': [5, 10, 15]},
    "Decision Tree": {'max_depth': [5, 10, 15]},
   # "Gradient Boosting": {'n_estimators': [100, 200, 300], 'max_depth': [5, 10, 15]},
    "Linear Regression": {},
    "Ridge": {},
    "XGBRegressor": {'n_estimators': [100, 200, 300], 'max_depth': [5, 10, 15]},
    "AdaBoost": {'n_estimators': [100, 200, 300]}
}

# %% [markdown]
# Grid search CV

# %%
def perform_grid_search(model_name, model, param_grid, X_train, y_train, X_test, y_test):
    grid_model = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='r2')
    grid_model.fit(X_train, y_train)

    # Make predictions
    y_train_pred = grid_model.predict(X_train)
    y_test_pred = grid_model.predict(X_test)

    # Test set performance
    r2, MAE, MSE, rmse = evaluate_reg(y_test, y_test_pred)
    r2_train, MAE_train, MSE_train, rmse_train = evaluate_reg(y_train, y_train_pred)

    result = {
        'Model': model_name,
        'r2_score': r2,
        'MAE': MAE,
        'MSE': MSE,
        'rmse': rmse,
        'r2_train': r2_train,
        'MAE_train': MAE_train,
        'MSE_train': MSE_train,
        'rmse_train': rmse_train
    }

    return grid_model.best_params_, result

# %% [markdown]
# Results

# %%
def get_results(models, param_grid, X_train, y_train, X_test, y_test):
    best_model_test_r2 = None
    best_test_r2_score = -float('inf')
    best_model_params = None
    results = pd.DataFrame(columns=['Model', 'r2_score', 'r2_train', 'MAE', 'MSE', 'rmse', 'MAE_train', 'MSE_train', 'rmse_train'])

    for model_name, model in models.items():
        param_grid_model = param_grid[model_name]
        best_params, result = perform_grid_search(model_name, model, param_grid_model, X_train, y_train, X_test, y_test)

        result['Best parameters'] = best_params

        results = results.append(result, ignore_index=True)

        # Update best model based on test R2 score
        if result['r2_score'] > best_test_r2_score:
            best_test_r2_score = result['r2_score']
            best_model_test_r2 = model_name
            best_model_params = best_params

    return results, best_model_test_r2, best_model_params

# %%
results,best_model,best_model_params = get_results(models, param_grid, X_train, y_train, X_test, y_test)
print(results)
# Out:
#                Model  r2_score  r2_train       MAE        MSE      rmse  \
# 0      Random Forest  0.907270  0.981233  3.648560  27.663646  5.259624
# 1      Decision Tree  0.900381  0.994201  3.738085  29.718703  5.451486
# 2  Linear Regression  0.782972  0.789211  6.181111  64.744970  8.046426
# 3              Ridge  0.728935  0.757797  6.993743  80.865487  8.992524
# 4       XGBRegressor  0.940698  0.992752  2.866294  17.691401  4.206115
# 5           AdaBoost  0.791324  0.813276  6.339784  62.253150  7.890067
#
#    MAE_train  MSE_train  rmse_train                         Best parameters
# 0   1.478676   4.812093    2.193648  {'max_depth': 15, 'n_estimators': 100}
# 1   0.228362   1.486968    1.219413                       {'max_depth': 15}
# 2   5.685751  54.049351    7.351826                                      {}
# 3   6.265463  62.104495    7.880641                                      {}
# 4   0.596116   1.858430    1.363242   {'max_depth': 5, 'n_estimators': 200}
# 5   5.800490  47.878766    6.919448                   {'n_estimators': 100}

# %%
best_model
# Out:
# 'XGBRegressor'

# %%
# Out:
# {'max_depth': 5, 'n_estimators': 200}

# %%
results
# Out:
#                Model  r2_score  r2_train       MAE        MSE      rmse  \
# 0      Random Forest  0.907270  0.981233  3.648560  27.663646  5.259624
# 1      Decision Tree  0.900381  0.994201  3.738085  29.718703  5.451486
# 2  Linear Regression  0.782972  0.789211  6.181111  64.744970  8.046426
# 3              Ridge  0.728935  0.757797  6.993743  80.865487  8.992524
# 4       XGBRegressor  0.940698  0.992752  2.866294  17.691401  4.206115
# 5           AdaBoost  0.791324  0.813276  6.339784  62.253150  7.890067
#
#    MAE_train  MSE_train  rmse_train                         Best parameters
# 0   1.478676   4.812093    2.193648  {'max_depth': 15, 'n_estimators': 100}
# 1   0.228362   1.486968    1.219413                       {'max_depth': 15}
# 2   5.685751  54.049351    7.351826                                      {}
# 3   6.265463  62.104495    7.880641                                      {}
# 4   0.596116   1.858430    1.363242   {'max_depth': 5, 'n_estimators': 200}
# 5   5.800490  47.878766    6.919448                   {'n_estimators': 100}

# %% [markdown]
# Selecting Model with best R2 Score - XGB Regressor

# %%
selected_columns
# Out:
# ['CementComponent ',
#  'AgeInDays',
#  'WaterComponent',
#  'BlastFurnaceSlag',
#  'SuperplasticizerComponent']

# %% [markdown]
# #### Model Training - Best Model - Hyper Paramters

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# Define your XGBoost regressor
xgb_regressor = xgb.XGBRegressor()

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [100, 200, 300],  # Example values, you can adjust these
    'max_depth': [3, 4, 5],
    'learning_rate': [0.1, 0.01, 0.001],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'reg_alpha': [0, 0.1, 0.5],
    'reg_lambda': [0, 0.1, 0.5],
    'gamma': [0, 0.1, 0.5]
}
grid_search = GridSearchCV(estimator=xgb_regressor, param_grid=param_grid, cv=3, scoring='r2')
grid_search.fit(X_train, y_train)  # X_train and y_train are your training data

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Retrain the model with the best parameters
best_xgb_regressor = xgb.XGBRegressor(**best_params)
best_xgb_regressor.fit(X_train, y_train)

# Evaluate the model on the test set

y_pred = best_xgb_regressor.predict(X_test)

# %%
def calculate_r2_score(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    return r2
calculate_r2_score(y_true=y_test,y_pred=y_pred)
# Out:
# 0.9363862013022404

# %% [markdown]
# Converting arrays to dataframe

# %%
def convert_to_dataframe(X_train, X_test, y_train, y_test,feature_column_list):
    X_train_df = pd.DataFrame(X_train, columns=feature_column_list)
    X_test_df = pd.DataFrame(X_test, columns=feature_column_list)
    y_train_df = pd.DataFrame(y_train, columns=['Strength'])
    y_test_df = pd.DataFrame(y_test, columns=['Strength'])

    return X_train_df, X_test_df, y_train_df,y_test_df
X_train_df, X_test_df, y_train_df,y_test_df=convert_to_dataframe(X_train=X_train,X_test=X_test,y_train=y_train,y_test=y_test,feature_column_list=selected_columns)

# %%
X_train_df.head()
# Out:
#    CementComponent   AgeInDays  WaterComponent  BlastFurnaceSlag  \
# 0          1.475745   0.463277        8.217200          1.712971
# 1          3.945246   0.463277        8.353293          0.253092
# 2          2.559757   0.049637        7.485113          0.000000
# 3          2.344816   0.463277        9.104150          1.115905
# 4          1.571585   0.049637        7.428799          0.485476
#
#    SuperplasticizerComponent
# 0                   2.515244
# 1                   1.425305
# 2                   1.660061
# 3                   1.341464
# 4                   1.810976

# %%
y_train_df.head()
# Out:
#      Strength
# 995     27.68
# 507     62.05
# 334     23.80
# 848     33.40
# 294      7.40

# %%
def plot_feature_importance(feature_names, importances, model_name):
    # Sort feature importances in descending order
    indices = np.argsort(importances)[::-1]
    sorted_feature_names = [str(feature_names[i]) for i in indices]
    sorted_importances = importances[indices]

    # Plot feature importances
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(importances)), sorted_importances, align='center')
    plt.xticks(range(len(importances)), sorted_feature_names, rotation=90)
    plt.xlabel('Features')
    plt.ylabel('Importance')
    plt.title(f'Feature Importance - {model_name}')
    plt.tight_layout()
    plt.show()

# %%
def predict_with_best_model(best_model, best_params, X_train, y_train, X_test):
    model = models[best_model]  # Retrieve the best model object
    model.set_params(**best_params)  # Set the best parameters for the model
    model.fit(X_train, y_train)  # Train the model with the best parameters

    # Make predictions on the test data
    y_pred = model.predict(X_test)

    # Get feature importances if available
    if hasattr(model, 'feature_importances_'):
        feature_names = X_train.columns
        importances = model.feature_importances_
        plot_feature_importance(feature_names, importances, best_model)

    return y_pred




y_pred=predict_with_best_model(best_model=best_model,best_params=best_model_params, X_train=X_train_df, y_train=y_train_df, X_test=X_test_df)

# %%
def calculate_r2_score(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    return r2

# %%
calculate_r2_score(y_test, y_pred)
# Out:
# 0.9300229535854061

# %% [markdown]
# Checking Predicted Values

# %%
def print_model_accuracy(y_test, y_pred):
    print('\n##### Model Validation and Accuracy Calculations ##########')

    # Creating a DataFrame to display sample values of prediction
    testing_data_results = pd.DataFrame({
        'Actual': y_test['Strength'],
        'Predicted': np.round(y_pred)
    }, index=y_test.index)

    print(testing_data_results.head())
    
    return testing_data_results

# Example usage with DataFrames
TestingDataResults=print_model_accuracy(y_test_df, y_pred)
# Out:
# ##### Model Validation and Accuracy Calculations ##########
#      Actual  Predicted
# 31    52.91       52.0
# 109   55.90       42.0
# 136   74.50       71.0
# 88    35.30       34.0
# 918   10.54        9.0

# %% [markdown]
# Error for each row

# %%
# Calculating the error for each row
TestingDataResults['APE']=100 * ((abs(
  TestingDataResults['Actual']-TestingDataResults['Predicted']))/TestingDataResults['Actual'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100- MedianMAPE
print('Mean Accuracy on test data:', Accuracy) # Can be negative sometimes due to outlier
print('Median Accuracy on test data:', MedianAccuracy)


# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    #print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)
# Out:
# Mean Accuracy on test data: 90.97953160980194
# Median Accuracy on test data: 93.86782114731328

# %%
# Custom Scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)
custom_Scoring
# Out:
# make_scorer(Accuracy_Score)

# %% [markdown]
# Cross Validation

# %%
model=best_model
# Out:
# 'XGBRegressor'

# %%
best_model_params
# Out:
# {'max_depth': 5, 'n_estimators': 100}

# %% [markdown]
# Cross validation

# %%
import numpy as np
import xgboost as xgb
from sklearn.model_selection import cross_val_score


def cross_validate_xgboost(X, y, n_folds=10, params=None, eval_metric=None, test_size=0.2, random_state=42):
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # Create an XGBoost model with the provided parameters
    xgb_model = xgb.XGBRegressor(**params) if params else xgb.XGBRegressor()

    # Perform cross-validation
    scores = cross_val_score(xgb_model, X_train, y_train, cv=n_folds, scoring=eval_metric)

    # Print the performance metric for each fold
    for i, score in enumerate(scores):
        print(f"Fold {i+1}: {score}")

    # Return the average performance metric across all folds
    avg_score = scores.mean()
    print(f"\nAverage : {avg_score}")

    # Return the best score obtained during cross-validation
    best_score = max(scores)
    print(f"Best : {best_score}")

    return best_score

avg_score=cross_validate_xgboost(X=X,y=y,params=best_model_params)
# Out:
# Fold 1: 0.9147356159665337
# Fold 2: 0.9278948035805545
# Fold 3: 0.9343564227942386
# Fold 4: 0.8824333741375481
# Fold 5: 0.9629063475340391
# Fold 6: 0.9028441492882836
# Fold 7: 0.9404919019261826
# Fold 8: 0.9403731277713815
# Fold 9: 0.9277136342105967
# Fold 10: 0.9096714587127362
#
# Average : 0.9243420835922095
# Best : 0.9629063475340391

# %% [markdown]
# #### Feature selection

# %% [markdown]
# 1. Reducible
# 2. Irreducible

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS

LR = LinearRegression()

exh = EFS(LR, max_features=6, scoring='accuracy', cv=5)
sel = exh.fit(X_train, y_train)

# %%
lr = LinearRegression()

exh = EFS(lr, max_features=6, scoring='accuracy', cv=5)

# %%
X_train
# Out:
# array([[ 1.47574514,  1.71297114,  1.81358251, ...,  2.51524418,
#         12.12127161,  0.46327707],
#        [ 3.94524552,  0.25309177,  2.06373182, ...,  1.42530503,
#         10.45178355,  0.46327707],
#        [ 2.55975718,  0.        ,  1.8980079 , ...,  1.66006116,
#         13.39659264,  0.04963683],
#        ...,
#        [ 1.77070807,  0.        ,  1.95741836, ...,  1.66006116,
#         13.7195553 ,  1.65456096],
#        [ 4.41979156,  1.36669557,  0.        , ...,  1.49237821,
#         10.83450701,  0.46327707],
#        [ 2.92171485,  0.        ,  1.76667951, ...,  1.67682945,
#         11.76143526,  0.46327707]])

# %%
y_train=np.array(y_train)
y_train
# Out:
# array([[27.68],
#        [62.05],
#        [23.8 ],
#        [33.4 ],
#        [ 7.4 ],
#        [27.77],
#        [18.29],
#        [48.59],
#        [39.7 ],
#        [ 4.57],
#        [13.29],
#        [36.97],
#        [22.53],
#        [71.3 ],
#        [25.61],
#        [76.24],
#        [62.94],
#        [17.54],
#        [41.05],
#        [21.86],
#        [47.13],
#        [16.5 ],
#        [22.72],
#        [29.72],
#        [19.93],
#        [ 9.62],
#        [39.05],
#        [42.13],
#        [39.32],
#        [34.49],
#        [28.1 ],
#        [38.6 ],
#        [53.77],
#        [ 7.32],
#        [32.82],
#        [43.38],
#        [55.16],
#        [35.23],
#        [66.7 ],
#        [30.88],
#        [76.8 ],
#        [17.96],
#        [55.06],
#        [64.3 ],
#        [33.8 ],
#        [45.94],
#        [37.26],
#        [24.85],
#        [40.15],
#        [13.54],
#        [32.88],
#        [17.57],
#        [21.54],
#        [17.84],
#        [23.4 ],
#        [55.55],
#        [17.6 ],
#        [31.42],
#        [13.82],
#        [65.91],
#        [81.75],
#        [28.8 ],
#        [42.8 ],
#        [42.13],
#        [13.33],
#        [12.47],
#        [27.42],
#        [32.04],
#        [39.4 ],
#        [33.4 ],
#        [28.3 ],
#        [15.36],
#        [41.1 ],
#        [23.84],
#        [43.25],
#        [34.57],
#        [10.22],
#        [39.09],
#        [24.66],
#        [22.95],
#        [47.03],
#        [18.13],
#        [33.4 ],
#        [45.7 ],
#        [31.12],
#        [20.73],
#        [36.56],
#        [12.46],
#        [32.66],
#        [38.5 ],
#        [25.18],
#        [17.95],
#        [19.2 ],
#        [26.2 ],
#        [15.52],
#        [11.41],
#        [60.29],
#        [69.84],
#        [24.92],
#        [36.3 ],
#        [32.33],
#        [39.29],
#        [66.82],
#        [25.72],
#        [17.54],
#        [25.2 ],
#        [23.64],
#        [33.76],
#        [13.29],
#        [13.36],
#        [51.06],
#        [24.48],
#        [65.91],
#        [25.57],
#        [44.03],
#        [32.85],
#        [13.46],
#        [38.11],
#        [74.99],
#        [79.3 ],
#        [15.53],
#        [46.39],
#        [12.18],
#        [ 9.85],
#        [33.7 ],
#        [23.25],
#        [36.45],
#        [77.3 ],
#        [25.56],
#        [38.46],
#        [23.52],
#        [21.86],
#        [37.81],
#        [19.69],
#        [37.43],
#        [26.05],
#        [38.89],
#        [26.15],
#        [11.48],
#        [33.06],
#        [15.69],
#        [67.31],
#        [28.63],
#        [32.07],
#        [39.45],
#        [39.23],
#        [39.38],
#        [27.34],
#        [31.54],
#        [41.3 ],
#        [58.8 ],
#        [45.08],
#        [51.72],
#        [55.51],
#        [23.85],
#        [68.75],
#        [53.1 ],
#        [15.03],
#        [67.7 ],
#        [17.58],
#        [39.94],
#        [24.5 ],
#        [11.96],
#        [67.11],
#        [79.99],
#        [23.35],
#        [33.94],
#        [17.54],
#        [13.09],
#        [57.23],
#        [19.99],
#        [23.74],
#        [44.87],
#        [65.2 ],
#        [56.4 ],
#        [12.79],
#        [23.7 ],
#        [33.69],
#        [32.72],
#        [40.6 ],
#        [28.99],
#        [82.6 ],
#        [63.53],
#        [17.22],
#        [29.87],
#        [71.99],
#        [31.27],
#        [52.2 ],
#        [34.67],
#        [ 6.47],
#        [50.6 ],
#        [72.3 ],
#        [44.86],
#        [31.88],
#        [ 4.78],
#        [66.  ],
#        [53.46],
#        [65.2 ],
#        [37.43],
#        [26.91],
#        [34.56],
#        [29.59],
#        [11.39],
#        [37.17],
#        [65.2 ],
#        [25.12],
#        [64.9 ],
#        [68.1 ],
#        [43.7 ],
#        [14.7 ],
#        [43.73],
#        [38.8 ],
#        [36.3 ],
#        [ 9.69],
#        [32.53],
#        [49.97],
#        [69.3 ],
#        [29.59],
#        [13.18],
#        [25.48],
#        [ 9.45],
#        [ 2.33],
#        [71.3 ],
#        [32.77],
#        [39.27],
#        [50.73],
#        [31.81],
#        [24.45],
#        [43.7 ],
#        [38.21],
#        [47.1 ],
#        [33.7 ],
#        [41.93],
#        [35.85],
#        [37.42],
#        [31.9 ],
#        [49.77],
#        [41.2 ],
#        [52.52],
#        [14.99],
#        [56.34],
#        [24.39],
#        [10.54],
#        [24.58],
#        [56.62],
#        [58.61],
#        [46.93],
#        [78.8 ],
#        [54.32],
#        [38.22],
#        [31.02],
#        [37.43],
#        [19.52],
#        [13.46],
#        [43.89],
#        [21.48],
#        [33.27],
#        [49.25],
#        [15.62],
#        [47.97],
#        [40.56],
#        [12.64],
#        [44.52],
#        [24.44],
#        [38.02],
#        [53.96],
#        [35.3 ],
#        [51.73],
#        [55.25],
#        [42.7 ],
#        [21.6 ],
#        [35.96],
#        [30.45],
#        [21.26],
#        [43.58],
#        [43.01],
#        [79.3 ],
#        [56.63],
#        [35.75],
#        [20.28],
#        [33.54],
#        [20.97],
#        [23.22],
#        [26.32],
#        [25.22],
#        [46.68],
#        [50.94],
#        [24.34],
#        [26.85],
#        [56.5 ],
#        [22.35],
#        [33.95],
#        [11.36],
#        [43.39],
#        [14.6 ],
#        [44.33],
#        [66.6 ],
#        [44.3 ],
#        [33.66],
#        [29.07],
#        [45.3 ],
#        [25.62],
#        [15.52],
#        [29.  ],
#        [46.24],
#        [59.09],
#        [57.92],
#        [33.04],
#        [22.9 ],
#        [12.18],
#        [39.3 ],
#        [49.77],
#        [29.87],
#        [14.2 ],
#        [ 7.68],
#        [28.02],
#        [41.37],
#        [17.24],
#        [39.  ],
#        [74.19],
#        [15.61],
#        [37.23],
#        [29.55],
#        [26.92],
#        [57.22],
#        [ 8.37],
#        [15.87],
#        [42.55],
#        [38.77],
#        [52.91],
#        [20.59],
#        [21.78],
#        [32.72],
#        [28.63],
#        [79.3 ],
#        [54.9 ],
#        [24.13],
#        [ 8.06],
#        [63.14],
#        [10.79],
#        [52.44],
#        [36.99],
#        [20.73],
#        [21.18],
#        [37.91],
#        [40.57],
#        [12.05],
#        [46.2 ],
#        [37.81],
#        [40.86],
#        [33.19],
#        [13.62],
#        [33.42],
#        [39.16],
#        [80.2 ],
#        [37.8 ],
#        [31.35],
#        [53.72],
#        [40.71],
#        [33.73],
#        [40.23],
#        [46.68],
#        [39.44],
#        [59.8 ],
#        [32.84],
#        [32.11],
#        [17.2 ],
#        [50.51],
#        [60.29],
#        [61.09],
#        [51.02],
#        [27.83],
#        [ 9.13],
#        [ 9.73],
#        [26.23],
#        [15.34],
#        [47.82],
#        [15.05],
#        [17.37],
#        [24.99],
#        [46.9 ],
#        [44.28],
#        [11.85],
#        [31.35],
#        [47.74],
#        [37.27],
#        [ 3.32],
#        [23.14],
#        [47.4 ],
#        [ 9.99],
#        [35.31],
#        [64.3 ],
#        [50.7 ],
#        [48.4 ],
#        [61.23],
#        [39.78],
#        [59.3 ],
#        [12.46],
#        [64.9 ],
#        [40.15],
#        [39.3 ],
#        [25.46],
#        [28.68],
#        [42.62],
#        [15.57],
#        [32.96],
#        [30.12],
#        [19.42],
#        [43.94],
#        [44.39],
#        [42.23],
#        [79.3 ],
#        [25.69],
#        [36.8 ],
#        [ 7.72],
#        [16.26],
#        [23.52],
#        [54.9 ],
#        [35.57],
#        [17.34],
#        [22.49],
#        [11.47],
#        [56.14],
#        [55.5 ],
#        [42.03],
#        [26.31],
#        [15.42],
#        [18.03],
#        [22.14],
#        [35.1 ],
#        [34.29],
#        [12.84],
#        [73.3 ],
#        [34.74],
#        [39.49],
#        [36.94],
#        [69.66],
#        [39.66],
#        [42.13],
#        [15.07],
#        [37.27],
#        [35.08],
#        [36.44],
#        [77.3 ],
#        [40.93],
#        [59.2 ],
#        [39.36],
#        [65.7 ],
#        [26.26],
#        [40.87],
#        [36.8 ],
#        [21.97],
#        [10.09],
#        [39.3 ],
#        [44.21],
#        [36.94],
#        [41.54],
#        [17.82],
#        [41.15],
#        [37.33],
#        [38.2 ],
#        [36.35],
#        [18.02],
#        [18.  ],
#        [37.72],
#        [16.11],
#        [37.36],
#        [16.28],
#        [44.28],
#        [42.64],
#        [26.23],
#        [40.66],
#        [74.17],
#        [12.45],
#        [33.72],
#        [13.2 ],
#        [59.59],
#        [43.8 ],
#        [31.87],
#        [22.63],
#        [40.06],
#        [17.28],
#        [64.9 ],
#        [ 9.01],
#        [77.3 ],
#        [54.6 ],
#        [39.38],
#        [31.45],
#        [55.9 ],
#        [24.24],
#        [10.35],
#        [49.2 ],
#        [34.24],
#        [16.88],
#        [14.2 ],
#        [14.54],
#        [27.92],
#        [ 6.94],
#        [61.8 ],
#        [49.19],
#        [73.7 ],
#        [59.  ],
#        [ 9.74],
#        [34.2 ],
#        [25.89],
#        [26.97],
#        [18.13],
#        [45.85],
#        [46.25],
#        [30.08],
#        [48.99],
#        [ 4.9 ],
#        [42.35],
#        [48.97],
#        [31.84],
#        [39.7 ],
#        [12.54],
#        [30.96],
#        [44.09],
#        [44.4 ],
#        [25.08],
#        [39.15],
#        [12.55],
#        [66.1 ],
#        [58.78],
#        [30.14],
#        [27.23],
#        [27.74],
#        [25.18],
#        [22.75],
#        [36.96],
#        [55.2 ],
#        [64.3 ],
#        [52.61],
#        [46.23],
#        [14.99],
#        [29.23],
#        [50.08],
#        [56.06],
#        [42.29],
#        [24.89],
#        [60.29],
#        [19.01],
#        [21.95],
#        [60.2 ],
#        [44.61],
#        [33.96],
#        [24.1 ],
#        [13.12],
#        [48.67],
#        [67.87],
#        [66.9 ],
#        [67.8 ],
#        [35.34],
#        [41.41],
#        [30.23],
#        [ 8.49],
#        [37.42],
#        [47.22],
#        [52.45],
#        [41.64],
#        [39.84],
#        [71.3 ],
#        [26.06],
#        [53.58],
#        [28.63],
#        [19.69],
#        [40.86],
#        [17.96],
#        [10.76],
#        [12.73],
#        [19.01],
#        [29.39],
#        [40.68],
#        [23.52],
#        [27.53],
#        [32.4 ],
#        [33.8 ],
#        [56.83],
#        [33.31],
#        [72.1 ],
#        [45.08],
#        [42.64],
#        [27.22],
#        [61.46],
#        [56.1 ],
#        [ 6.81],
#        [50.77],
#        [23.79],
#        [18.42],
#        [20.42],
#        [46.23],
#        [39.46],
#        [31.42],
#        [53.9 ],
#        [42.42],
#        [15.75],
#        [44.14],
#        [29.89],
#        [21.29],
#        [22.93],
#        [32.1 ],
#        [66.95],
#        [42.92],
#        [14.5 ],
#        [ 7.84],
#        [30.57],
#        [36.64],
#        [31.97],
#        [41.37],
#        [ 7.75],
#        [39.06],
#        [52.82],
#        [44.42],
#        [46.64],
#        [37.92],
#        [43.7 ],
#        [31.18],
#        [51.04],
#        [23.79],
#        [28.94],
#        [27.63],
#        [ 8.54],
#        [15.42],
#        [19.54],
#        [25.56],
#        [32.63],
#        [15.57],
#        [18.2 ],
#        [61.92],
#        [28.6 ],
#        [31.35],
#        [41.68],
#        [23.74],
#        [79.4 ],
#        [59.49],
#        [38.41],
#        [24.4 ],
#        [57.6 ],
#        [24.29],
#        [30.65],
#        [32.24],
#        [36.44],
#        [29.07],
#        [33.61],
#        [49.2 ],
#        [21.82],
#        [22.32],
#        [54.28],
#        [ 7.51],
#        [23.52],
#        [49.99],
#        [25.42],
#        [33.3 ],
#        [35.86],
#        [24.9 ],
#        [47.28],
#        [26.74],
#        [29.16],
#        [27.92],
#        [32.96],
#        [38.56],
#        [44.3 ],
#        [39.  ],
#        [20.87],
#        [23.89],
#        [25.97],
#        [18.91],
#        [31.97],
#        [38.7 ],
#        [ 8.54],
#        [36.59],
#        [55.6 ],
#        [39.58],
#        [17.44],
#        [38.7 ],
#        [14.4 ],
#        [33.49],
#        [40.76],
#        [41.72],
#        [25.18],
#        [26.86],
#        [21.06],
#        [71.3 ],
#        [52.12],
#        [28.99],
#        [30.39],
#        [25.51],
#        [24.  ],
#        [43.06],
#        [45.37],
#        [11.98],
#        [13.57],
#        [55.65],
#        [37.44],
#        [55.45],
#        [49.9 ],
#        [ 9.87],
#        [57.03],
#        [43.38],
#        [68.5 ],
#        [37.27],
#        [13.4 ],
#        [27.68],
#        [52.83],
#        [48.7 ],
#        [34.68],
#        [47.81],
#        [72.99],
#        [50.46],
#        [45.9 ],
#        [67.57],
#        [29.45],
#        [ 6.27],
#        [28.47],
#        [ 9.74],
#        [41.05],
#        [33.12],
#        [31.03],
#        [56.85],
#        [33.21],
#        [43.57],
#        [35.76],
#        [23.51],
#        [50.53],
#        [29.22],
#        [14.31],
#        [53.66],
#        [51.26],
#        [26.77],
#        [33.8 ],
#        [35.23],
#        [15.44],
#        [26.4 ],
#        [59.89],
#        [27.94],
#        [37.91],
#        [58.52],
#        [17.17],
#        [25.02],
#        [20.77],
#        [13.52],
#        [54.1 ],
#        [14.84],
#        [44.13],
#        [61.89],
#        [35.87],
#        [37.92],
#        [33.08],
#        [15.34],
#        [33.4 ],
#        [20.92],
#        [53.69],
#        [40.93],
#        [22.44],
#        [32.01],
#        [19.42],
#        [39.64],
#        [61.24],
#        [52.2 ],
#        [35.3 ],
#        [21.91],
#        [40.93],
#        [21.07],
#        [33.73],
#        [21.16],
#        [24.54],
#        [42.33],
#        [33.36],
#        [27.04],
#        [51.02],
#        [45.84],
#        [62.5 ],
#        [45.3 ],
#        [41.84],
#        [47.71],
#        [55.94],
#        [54.77],
#        [41.54],
#        [29.55],
#        [16.5 ],
#        [40.86],
#        [32.05],
#        [18.28],
#        [24.07],
#        [33.42],
#        [14.14],
#        [29.73],
#        [10.38],
#        [21.65],
#        [43.58],
#        [ 9.56],
#        [35.36],
#        [24.28],
#        [39.  ],
#        [50.95],
#        [53.39],
#        [25.75],
#        [40.87],
#        [26.06],
#        [38.33],
#        [28.24],
#        [52.04],
#        [55.02],
#        [77.3 ],
#        [29.65],
#        [32.25],
#        [22.84],
#        [60.28],
#        [48.79],
#        [15.82],
#        [36.84],
#        [56.74],
#        [41.24],
#        [55.64],
#        [10.39],
#        [74.7 ],
#        [27.87],
#        [32.76],
#        [24.4 ],
#        [42.22],
#        [33.56],
#        [68.3 ],
#        [38.46]])

# %%
sel = exh.fit(X_train, y_train)
# Out:
# Features: 126/126
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 sel = exh.fit(X_train, y_train)
#
# File c:\Users\Hitesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py:482, in ExhaustiveFeatureSelector.fit(self, X, y, groups, **fit_params)
#     480 else:
#     481     self.fitted = True  # the completion of sequential selection process.
# --> 482     self.finalize_fit()
#     484 return self
#
# File c:\Users\Hitesh\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py:493, in ExhaustiveFeatureSelector.finalize_fit(self)
#     490         best_subset = c
#     491         max_score = self.subsets_[c]["avg_score"]
# --> 493 self.best_idx_ = self.subsets_[best_subset]["feature_idx"]
#     494 self.best_score_ = max_score
#     495 self.subsets_, self.best_feature_names_ = _get_featurenames(
#     496     self.subsets_, self.best_idx_, self.feature_names, self.n_features
#     497 )
#
# UnboundLocalError: cannot access local variable 'best_subset' where it is not associated with a value

# %%
sel.best_score_

# %%
sel.best_feature_names_

# %% [markdown]
# Backward elimination
